# %%
# read and explore the dataset

# get dataset
with open("names.txt") as f:
    words = f.read().splitlines()

print(words[1:10])
# Out:
# ['olivia', 'ava', 'isabella', 'sophia', 'charlotte', 'mia', 'amelia', 'harper', 'evelyn']

# %%
# build bigram correlation matrix

b = {}
for w in words:
    w = ['<S>'] + list(w) + ['<E>']
    for ch1, ch2 in zip(w,w[1:]):
        bigram = (ch1, ch2)
        b[bigram] = b.get(bigram, 0) + 1

sorted(b.items(), key = lambda kv: -kv[1])

# plot the matrix
import torch
N = torch.zeros((27, 27), dtype=torch.int32)

# %%
# build encoder and decoder

chars = sorted(list(set("".join(words))))
stoi = {v : i + 1 for i,v in enumerate(chars)}
stoi['.'] = 0
itos = {i + 1 : v for i,v in enumerate(chars)}
itos[0] = '.'

# Populate the matrix

for word in words:
    chs = '.' + list(word) + '.'
    for ch1, ch2 in zip(chs, chs[1:]):
        idx1 = stoi[ch1]
        idx2 = stoi[ch2]
        N[idx1, idx2] += 1
